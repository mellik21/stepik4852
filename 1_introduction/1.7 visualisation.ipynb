# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("income.csv", encoding = 'UTF-8', delimiter=',')
df
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.index, df.income)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['income'].plot()
# Out:
# <AxesSubplot:>

# %%
df.income.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("dataset_209770_6.txt", sep=" ")
df
# Out:
#               x            y
# 0    209.324713   616.996397
# 1    301.393025   991.543583
# 2    822.416080   695.969792
# 3   1003.379237  1083.384622
# 4   1094.217318   207.257991
# ..          ...          ...
# 65   284.699948  1008.607954
# 66  1482.560200  1489.245428
# 67   793.988871   699.524818
# 68   684.649518   488.221589
# 69  1004.491663  1090.005242
#
# [70 rows x 2 columns]

# %%
sns.scatterplot(x='x',y='y', data=df)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df = pd.read_csv("genome_matrix.csv", sep=",", index_col='Unnamed: 0')
df
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
g = sns.heatmap(df, center=0,cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
df = pd.read_csv("dota_hero_stats.csv", sep=",")
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
data = df['roles'].str.count(',')
data.mean()+1
# Out:
# 4.0

# %%
sns_plot = sns.histplot(data)
fig = sns_plot.get_figure()

# %%
df = pd.read_csv("iris.csv", sep=",",  index_col='Unnamed: 0')
df
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.distplot(df['sepal length'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal length', ylabel='Density'>

# %%
sns.distplot(df['sepal width'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal width', ylabel='Density'>

# %%
sns.distplot(df['petal length'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal length', ylabel='Density'>

# %%
sns.distplot(df['petal width'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='petal width', ylabel='Density'>

# %%
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x=df["petal length"])

# %%
sns.set_theme(style="whitegrid")
ax = sns.scatterplot(data=df,x='petal length',y='petal width')

# %%
sns.set_theme(style="whitegrid")
ax = sns.scatterplot(data=df,x='sepal length',y='sepal width')
