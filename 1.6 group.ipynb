# %%
import pandas as pd
import numpy as np
data = pd.read_csv("dota_hero_stats.csv", encoding = 'UTF-8', delimiter=',')
data
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
len(data.query('legs==8'))
# Out:
# 1

# %%
data.groupby(by=['attack_type','primary_attr']).agg(['count'])
# Out:
#                          Unnamed: 0    id  legs localized_name  name roles
#                               count count count          count count count
# attack_type primary_attr
# Melee       agi                  19    19    19             19    19    19
#             int                   2     2     2              2     2     2
#             str                  35    35    35             35    35    35
# Ranged      agi                  18    18    18             18    18    18
#             int                  40    40    40             40    40    40
#             str                   3     3     3              3     3     3

# %%
data = pd.read_csv("accountancy.csv", encoding = 'UTF-8', delimiter=',')
data
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
data[data['Executor']=='Loopa']
# Out:
#     Unnamed: 0 Executor Type  Salary
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 14          14    Loopa    D     110
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 25          25    Loopa    C     175
# 26          26    Loopa    D      78
# 27          27    Loopa    C      81
# 32          32    Loopa    B     128
# 34          34    Loopa    B      69
# 35          35    Loopa    F     244
# 36          36    Loopa    E     122
# 37          37    Loopa    C     222
# 38          38    Loopa    D     181
# 40          40    Loopa    D     172
# 42          42    Loopa    E     220
# 43          43    Loopa    B     185
# 44          44    Loopa    C     249
# ...

# %%
data[data['Executor']=='Loopa'].groupby(by=["Type"]).agg(['max'])
# Out:
#      Unnamed: 0 Executor Salary
#             max      max    max
# Type
# A            46    Loopa     58
# B            43    Loopa    249
# C            47    Loopa    249
# D            49    Loopa    181
# E            42    Loopa    220
# F            35    Loopa    244

# %%
data[data['Executor']=='Pupa'].groupby(by=["Type"]).agg(['max'])
# Out:
#      Unnamed: 0 Executor Salary
#             max      max    max
# Type
# A            39     Pupa    234
# B            41     Pupa     77
# C            24     Pupa     94
# D            31     Pupa    194
# E            30     Pupa    197
# F            48     Pupa    195

# %%
concentrations = pd.read_csv("algae.csv", encoding = 'UTF-8', delimiter=',')
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
mean_concentrations = concentrations.groupby(['genus']).mean()
mean_concentrations
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
concentrations[concentrations['genus']=='Fucus']
# Out:
#              species  genus  group   sucrose    alanin   citrate   glucose  \
# 0  Fucus_vesiculosus  Fucus  brown  3.001472  3.711498  5.004262  2.548459
# 2     Fucus_serratus  Fucus  brown  3.276870  0.346431  1.216767  3.623225
# 3    Fucus_distichus  Fucus  brown  6.786996  6.641303  6.423606  2.272724
#
#    oleic_acid
# 0    6.405165
# 2    0.304573
# 3    3.393203

# %%
concentrations[concentrations['genus']=='Fucus']['alanin'].min()
# Out:
# 0.346431192312627

# %%
concentrations[concentrations['genus']=='Fucus']['alanin'].mean()
# Out:
# 3.5664107784705106

# %%
concentrations[concentrations['genus']=='Fucus']['alanin'].max()
# Out:
# 6.641303172624768

# %%
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...
