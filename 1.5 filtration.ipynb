# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("StudentsPerformance.csv", encoding = 'UTF-8', delimiter=',')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.shape[0]
# Out:
# 1000

# %%
data[data['lunch']=='free/reduced'].shape[0]
# Out:
# 355

# %%
355/1000
# Out:
# 0.355

# %%
math1=data[data['lunch']=='free/reduced']['math score'].mean()
read1=data[data['lunch']=='free/reduced']['reading score'].mean()
wtite1=data[data['lunch']=='free/reduced']['writing score'].mean()
#####

print(math1)
print(read1)
print(wtite1)
# Out:
# 58.92112676056338
# 64.65352112676057
# 63.02253521126761

# %%
math2=data[data['lunch']=='standard']['math score'].mean()
read2=data[data['lunch']=='standard']['reading score'].mean()
wtite2=data[data['lunch']=='standard']['writing score'].mean()

print(math2)
print(read2)
print(wtite2)
# Out:
# 70.03410852713178
# 71.65426356589147
# 70.8232558139535

# %%
math3=data[data['lunch']=='free/reduced']['math score'].var()
read3=data[data['lunch']=='free/reduced']['reading score'].var()
wtite3=data[data['lunch']=='free/reduced']['writing score'].var()
#####

print(math3)
print(read3)
print(wtite3)
# Out:
# 229.82426991326489
# 221.87113869658629
# 238.20288056019737

# %%
math4=data[data['lunch']=='standard']['math score'].var()
read4=data[data['lunch']=='standard']['reading score'].var()
wtite4=data[data['lunch']=='standard']['writing score'].var()

print(math4)
print(read4)
print(wtite4)
# Out:
# 186.41808946025327
# 191.28556020992824
# 205.62088689874338

# %%
data = data.rename(columns={'test preparation course':'test_preparation_course',
                   'math score':'math_score',
                   'reading score':'reading_score',
                   'writing score':'writing_score'})

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
data.query('math_score>70')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...
